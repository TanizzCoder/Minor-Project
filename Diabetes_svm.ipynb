# %% [markdown]
# <a href="https://colab.research.google.com/github/TanizzCoder/Minor-Project/blob/main/Diabetes_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5d620b7e-13d6-4552-9a71-5a269948c5d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d620b7e-13d6-4552-9a71-5a269948c5d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving D2.csv to D2.csv
# {'D2.csv': b'Pregnancies,Age,Glucose,SkinThickness,BMI,BloodPressure,Insulin,DiabetesPedigreeFunction,,Outcome\r\n6,50,148,35,33.6,72,0,0.627,,1\r\n1,31,85,29,26.6,66,0,0.351,,0\r\n8,32,183,0,23.3,64,0,0.672,,1\r\n1,21,89,23,28.1,66,94,0.167,,0\r\n0,33,137,35,43.1,40,168,2.288,,1\r\n5,30,116,0,25.6,74,0,0.201,,0\r\n3,26,78,32,31,50,88,0.248,,1\r\n10,29,115,0,35.3,0,0,0.134,,0\r\n2,53,197,45,30.5,70,543,0.158,,1\r\n8,54,125,0,0,96,0,0.232,,1\r\n4,30,110,0,37.6,92,0,0.191,,0\r\n10,34,168,0,38,74,0,0.537,,1\r\n10,57,139,0,27.1,80,0,1.441,,0\r\n1,59,189,23,30.1,60,846,0.398,,1\r\n5,51,166,19,25.8,72,175,0.587,,1\r\n7,32,100,0,30,0,0,0.484,,1\r\n0,31,118,47,45.8,84,230,0.551,,1\r\n7,31,107,0,29.6,74,0,0.254,,1\r\n1,33,103,38,43.3,30,83,0.183,,0\r\n1,32,115,30,34.6,70,96,0.529,,1\r\n3,27,126,41,39.3,88,235,0.704,,0\r\n8,50,99,0,35.4,84,0,0.388,,0\r\n7,41,196,0,39.8,90,0,0.451,,1\r\n9,29,119,35,29,80,0,0.263,,1\r\n11,51,143,33,36.6,94,146,0.254,,1\r\n10,41,125,26,31.1,70,115,0.205,,1\r\n7,43,147,0,39.4,76,0,0.257,,1\r\n1,22,97,15,23.2,66,140,0.487,,0\r\n13,57,145,19,22.2,82,110,0.245,,0\r\n5,38,117,0,34.1,92,0,0.337,,0\r\n5,60,109,26,36,75,0,0.546,,0\r\n3,28,158,36,31.6,76,245,0.851,,1\r\n3,22,88,11,24.8,58,54,0.267,,0\r\n6,28,92,0,19.9,92,0,0.188,,0\r\n10,45,122,31,27.6,78,0,0.512,,0\r\n4,33,103,33,24,60,192,0.966,,0\r\n11,35,138,0,33.2,76,0,0.42,,0\r\n9,46,102,37,32.9,76,0,0.665,,1\r\n2,27,90,42,38.2,68,0,0.503,,1\r\n4,56,111,47,37.1,72,207,1.39,,1\r\n3,26,180,25,34,64,70,0.271,,0\r\n7,37,133,0,40.2,84,0,0.696,,0\r\n7,48,106,18,22.7,92,0,0.235,,0\r\n9,54,171,24,45.4,110,240,0.721,,1\r\n7,40,159,0,27.4,64,0,0.294,,0\r\n0,25,180,39,42,66,0,1.893,,1\r\n1,29,146,0,29.7,56,0,0.564,,0\r\n2,22,71,27,28,70,0,0.586,,0\r\n7,31,103,32,39.1,66,0,0.344,,1\r\n7,24,105,0,0,0,0,0.305,,0\r\n1,22,103,11,19.4,80,82,0.491,,0\r\n1,26,101,15,24.2,50,36,0.526,,0\r\n5,30,88,21,24.4,66,23,0.342,,0\r\n8,58,176,34,33.7,90,300,0.467,,1\r\n7,42,150,42,34.7,66,342,0.718,,0\r\n1,21,73,10,23,50,0,0.248,,0\r\n7,41,187,39,37.7,68,304,0.254,,1\r\n0,31,100,60,46.8,88,110,0.962,,0\r\n0,44,146,0,40.5,82,0,1.781,,0\r\n0,22,105,41,41.5,64,142,0.173,,0\r\n2,21,84,0,0,0,0,0.304,,0\r\n8,39,133,0,32.9,72,0,0.27,,1\r\n5,36,44,0,25,62,0,0.587,,0\r\n2,24,141,34,25.4,58,128,0.699,,0\r\n7,42,114,0,32.8,66,0,0.258,,1\r\n5,32,99,27,29,74,0,0.203,,0\r\n0,38,109,30,32.5,88,0,0.855,,1\r\n2,54,109,0,42.7,92,0,0.845,,0\r\n1,25,95,13,19.6,66,38,0.334,,0\r\n4,27,146,27,28.9,85,100,0.189,,0\r\n2,28,100,20,32.9,66,90,0.867,,1\r\n5,26,139,35,28.6,64,140,0.411,,0\r\n13,42,126,0,43.4,90,0,0.583,,1\r\n4,23,129,20,35.1,86,270,0.231,,0\r\n1,22,79,30,32,75,0,0.396,,0\r\n1,22,0,20,24.7,48,0,0.14,,0\r\n7,41,62,0,32.6,78,0,0.391,,0\r\n5,27,95,33,37.7,72,0,0.37,,0\r\n0,26,131,0,43.2,0,0,0.27,,1\r\n2,24,112,22,25,66,0,0.307,,0\r\n3,22,113,13,22.4,44,0,0.14,,0\r\n2,22,74,0,0,0,0,0.102,,0\r\n7,36,83,26,29.3,78,71,0.767,,0\r\n0,22,101,28,24.6,65,0,0.237,,0\r\n5,37,137,0,48.8,108,0,0.227,,1\r\n2,27,110,29,32.4,74,125,0.698,,0\r\n13,45,106,54,36.6,72,0,0.178,,0\r\n2,26,100,25,38.5,68,71,0.324,,0\r\n15,43,136,32,37.1,70,110,0.153,,1\r\n1,24,107,19,26.5,68,0,0.165,,0\r\n1,21,80,0,19.1,55,0,0.258,,0\r\n4,34,123,15,32,80,176,0.443,,0\r\n7,42,81,40,46.7,78,48,0.261,,0\r\n4,60,134,0,23.8,72,0,0.277,,1\r\n2,21,142,18,24.7,82,64,0.761,,0\r\n6,40,144,27,33.9,72,228,0.255,,0\r\n2,24,92,28,31.6,62,0,0.13,,0\r\n1,22,71,18,20.4,48,76,0.323,,0\r\n6,23,93,30,28.7,50,64,0.356,,0\r\n1,31,122,51,49.7,90,220,0.325,,1\r\n1,33,163,0,39,72,0,1.222,,1\r\n1,22,151,0,26.1,60,0,0.179,,0\r\n0,21,125,0,22.5,96,0,0.262,,0\r\n1,24,81,18,26.6,72,40,0.283,,0\r\n2,27,85,0,39.6,65,0,0.93,,0\r\n1,21,126,29,28.7,56,152,0.801,,0\r\n1,27,96,0,22.4,122,0,0.207,,0\r\n4,37,144,28,29.5,58,140,0.287,,0\r\n3,25,83,31,34.3,58,18,0.336,,0\r\n0,24,95,25,37.4,85,36,0.247,,1\r\n3,24,171,33,33.3,72,135,0.199,,1\r\n8,46,155,26,34,62,495,0.543,,1\r\n1,23,89,34,31.2,76,37,0.192,,0\r\n4,25,76,0,34,62,0,0.391,,0\r\n7,39,160,32,30.5,54,175,0.588,,1\r\n4,61,146,0 ...

# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd
# Importing the datasets
df = pd.read_csv('D2.csv')
df.head()
# Out:
#    Pregnancies  Age  Glucose  SkinThickness   BMI  BloodPressure  Insulin  \
# 0            6   50      148             35  33.6             72        0
# 1            1   31       85             29  26.6             66        0
# 2            8   32      183              0  23.3             64        0
# 3            1   21       89             23  28.1             66       94
# 4            0   33      137             35  43.1             40      168
#
#    DiabetesPedigreeFunction  Unnamed: 8  Outcome
# 0                     0.627         NaN        1
# 1                     0.351         NaN        0
# 2                     0.672         NaN        1
# 3                     0.167         NaN        0
# 4                     2.288         NaN        1

# %% [markdown]
# Applying SVM on the whole dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
x = df.iloc[:, :8]
y = df['Outcome']
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.2)
clf = svm.SVC(kernel='rbf')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
from sklearn.metrics import recall_score, precision_score, f1_score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Precision: ",precision)
print("Recall: ",recall)
print("f1: ",f1)
from sklearn.metrics import confusion_matrix
#print(confusion_matrix(y_test,y_pred))
print("\t\tConfusion Matrix")
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
# Out:
# Accuracy: 0.7922077922077922
# Precision:  0.7272727272727273
# Recall:  0.5106382978723404
# f1:  0.5999999999999999
# 		Confusion Matrix

# %%
# Out:
# Precision:  0.7272727272727273
# Recall:  0.5106382978723404
# f1:  0.5999999999999999

# %% [markdown]
# Applying SVM on four features

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
x = df.iloc[:, 1:5]
y = df['Outcome']
print(x[:5])
print()
print(y[:5])
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.2)
clf = svm.SVC(kernel='rbf')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
from sklearn.metrics import recall_score, precision_score, f1_score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Precision: ",precision)
print("Recall: ",recall)
print("f1: ",f1)
from sklearn.metrics import confusion_matrix
#print(confusion_matrix(y_test,y_pred))
print("\t\tConfusion Matrix")
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
# Out:
#    Age  Glucose  SkinThickness   BMI
# 0   50      148             35  33.6
# 1   31       85             29  26.6
# 2   32      183              0  23.3
# 3   21       89             23  28.1
# 4   33      137             35  43.1
#
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64
# Accuracy: 0.7727272727272727
# Precision:  0.6666666666666666
# Recall:  0.5106382978723404
# f1:  0.5783132530120482
# 		Confusion Matrix

# %%
# Out:
# Precision:  0.71875
# Recall:  0.48936170212765956
# f1:  0.5822784810126582

# %% [markdown]
# Applying SVM on two features

# %%
x = df.iloc[:, 1:3]
y = df['Outcome']
print(x[:5])
print()
print(y[:5])
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.2)
clf = svm.SVC(kernel='rbf')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
from sklearn.metrics import recall_score, precision_score, f1_score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Precision: ",precision)
print("Recall: ",recall)
print("f1: ",f1)
from sklearn.metrics import confusion_matrix
#print(confusion_matrix(y_test,y_pred))
print("\t\tConfusion Matrix")
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
# Out:
#    Age  Glucose
# 0   50      148
# 1   31       85
# 2   32      183
# 3   21       89
# 4   33      137
#
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64
# Accuracy: 0.7792207792207793
# Precision:  0.696969696969697
# Recall:  0.48936170212765956
# f1:  0.575
# 		Confusion Matrix

# %%
# Out:
# Precision:  0.696969696969697
# Recall:  0.48936170212765956
# f1:  0.575
